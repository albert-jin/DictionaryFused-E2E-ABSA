# %%
# !rm -rf DeBERTa
# !git clone https://github.com/huberemanuel/DeBERTa.git
# !pip install -r DeBERTa/requirements.txt
# Out:
# Cloning into 'DeBERTa'...
# remote: Enumerating objects: 409, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 409 (delta 103), reused 98 (delta 98), pack-reused 282
# Receiving objects: 100% (409/409), 414.13 KiB | 927.00 KiB/s, done.
# Resolving deltas: 100% (230/230), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 43 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 773.1 MB 12 kB/s
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=13af60343cdf626ff753e07f94a913da362ef0451248c780e60385d84a6b7b2d
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=5e04e7d314530048d7c22a277099f4ba831c58f632c6e1d3a5280346c10c6199
# ...

# %%
# !ls /content/DeBERTa
# Out:
# ABSA-DeBERTa	    DeBERTa	 LICENSE	   SECURITY.md
# calc.py		    docker	 README.md	   setup.cfg
# CODE_OF_CONDUCT.md  docs	 requirements.txt  setup.py
# data		    experiments  run_docker.sh	   VERSION

# %%
# !git clone https://github.com/albert-jin/DictionaryFused-E2E-ABSA.git
# !mkdir -p /tmp/DeBERTa/glue_tasks/QQP/
# Out:
# Cloning into 'DictionaryFused-E2E-ABSA'...
# remote: Enumerating objects: 183, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 183 (delta 97), reused 148 (delta 74), pack-reused 0
# Receiving objects: 100% (183/183), 2.07 MiB | 8.53 MiB/s, done.
# Resolving deltas: 100% (97/97), done.

# %%
# !head -n 5 /content/DictionaryFused-E2E-ABSA/datasets/acl14shortdata/output_know_insert/train.tsv
# Out:
# review	aspect	sentiment
#  xbox $ Of the head-yards of a sailing vessel: in a position with only the headsails laid aback. $ live : angielo is currently online . playing gears of war 2 . public execution on jacinto . -lrb- $t$ live nation -rrb-	xbox	0
#  sarah palin $ (in the Bible) the wife of Abraham and mother of Isaac (Gen. 17:15 ff.). Characterized by or involving backward motion, especially of the lower jaw in chewing. Contrasted with proal. $ is awesome . | yes she is !	sarah palin	1
# russell brand and katy perry $ a system of individual training exercises in karate and other martial arts in the slightest. [SEP] an alcoholic drink made from the fermented juice of pears. $ suit each other . they 're both weird .	katy perry	-1
# ...

# %%
# !head -n 10 /content/DictionaryFused-E2E-ABSA/datasets/laprest14/output_know_insert/train.tsv #git仓库将output文件夹还原成了aclshortdata文件夹了
# Out:
# review	aspect	sentiment
# I charge it at night and skip taking the cord $ thin, flexible string or rope made from several twisted strands ribbed fabric, especially corduroy a measure of cut wood (usually 128 cu. ft, 3.62 cubic metres). $ with me because of the good battery life.	cord	1
# """""""The tech guy $ technology. an educational institution specializing in technology or applied sciences; a technical college. [SEP] a man a figure representing Guy Fawkes, burnt on a bonfire on Guy Fawkes Night, and often displayed by children begging for money for fireworks."" $ then said the service center does not do 1-to-1 exchange and I have to direct my concern to the """"""""sales"""""""" team, which is the retail shop which I bought my netbook from."""""	tech guy	0
# ...

# %%
# !head -n 5 /content/DictionaryFused-E2E-ABSA/datasets/rest15/output_know_insert/train.tsv
# Out:
# review	aspect	sentiment
# We, there were four of us, arrived at noon - the place was empty - and the staff $ not found $ acted like we were imposing on them and they were very rude.	staff	-1
# The food $ any nutritious substance that people or animals eat or drink or that plants absorb in order to maintain life and growth $ was lousy - too sweet or too salty and the portions tiny.	food	-1
# Avoid this place $ a particular position, point, or area in space; a location a portion of space designated or available for or being used by someone a position in a sequence or series, typically one ordered on the basis of merit a square or short street $!	place	-1
# I have eaten at Saul, many times, the food $ any nutritious substance that people or animals eat or drink or that plants absorb in order to maintain life and growth $ is always consistently, outrageously good.	food	1

# %%
# !head -n 5 /content/DictionaryFused-E2E-ABSA/datasets/rest16/output_know_insert/train.tsv
# Out:
# review	aspect	sentiment
# Judging from previous posts this used to be a good place $ a particular position, point, or area in space; a location a portion of space designated or available for or being used by someone a position in a sequence or series, typically one ordered on the basis of merit a square or short street $, but not any longer.	place	-1
# We, there were four of us, arrived at noon - the place was empty - and the staff $ not found $ acted like we were imposing on them and they were very rude.	staff	-1
# The food $ any nutritious substance that people or animals eat or drink or that plants absorb in order to maintain life and growth $ was lousy - too sweet or too salty and the portions tiny.	food	-1
# Avoid this place $ a particular position, point, or area in space; a location a portion of space designated or available for or being used by someone a position in a sequence or series, typically one ordered on the basis of merit a square or short street $!	place	-1

# %%
# !head -n 5 /content/DictionaryFused-E2E-ABSA/datasets/twitter/output_know_insert/train.tsv
# Out:
# review	aspect	sentiment
# happy national day QATAR $ a sheikhdom occupying a peninsula on the west coast of the Persian Gulf; population 2,200,000 (estimated 2015); official language, Arabic; capital, Doha. The country was a British protectorate from 1916 until 1971, when it became a sovereign independent state. Oil is the chief source of revenue. $ & lt ; 3	QATAR	0
# Faisal Faisal Faisal Faisal Faisal Faisal Faisal Faisal Faisal Faisal Faisal Faisal $ the name of two kings of Iraq. $ !!! too many questions to answer ! #FamilysConsultant	Faisal Faisal Faisal Faisal Faisal Faisal Faisal Faisal Faisal Faisal Faisal Faisal	0
# """""""I posted 15 photos on Facebook $ spend time using the social media application Facebook"" $ in the album """"""""PICK IT UP 23/10/11"""""""" http://t.co/GO2tlMNc"""""	Facebook	0
# ...

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
# !head -n 10 /content/DictionaryFused-E2E-ABSA/datasets/rest15/output_know_insert/train.tsv
# Out:
# review	aspect	sentiment
# We, there were four of us, arrived at noon - the place was empty - and the staff $ not found $ acted like we were imposing on them and they were very rude.	staff	-1
# The food $ any nutritious substance that people or animals eat or drink or that plants absorb in order to maintain life and growth $ was lousy - too sweet or too salty and the portions tiny.	food	-1
# Avoid this place $ a particular position, point, or area in space; a location a portion of space designated or available for or being used by someone a position in a sequence or series, typically one ordered on the basis of merit a square or short street $!	place	-1
# I have eaten at Saul, many times, the food $ any nutritious substance that people or animals eat or drink or that plants absorb in order to maintain life and growth $ is always consistently, outrageously good.	food	1
# ...

# %% [markdown]
# 跑Twitter数据集  run twitter datasets (测试在twtter上加字典知识后INSERTION的效果)

# %%
# !cp /content/Git_repository1/output/twitter/train.tsv /tmp/DeBERTa/glue_tasks/QQP/train.tsv
# !cp /content/Git_repository1/output/twitter/dev.tsv /tmp/DeBERTa/glue_tasks/QQP/dev.tsv
# !cp /content/Git_repository1/output/twitter/test.tsv /tmp/DeBERTa/glue_tasks/QQP/test.tsv
#  /content/DictionaryFused-E2E-ABSA/datasets/rest15/output_know_insert/train.tsv
# !cp /content/DictionaryFused-E2E-ABSA/datasets/twitter/output_know_insert/train.tsv /tmp/DeBERTa/glue_tasks/QQP/train.tsv
# !cp /content/DictionaryFused-E2E-ABSA/datasets/twitter/output_know_insert/dev.tsv /tmp/DeBERTa/glue_tasks/QQP/dev.tsv
# !cp /content/DictionaryFused-E2E-ABSA/datasets/twitter/output_know_insert/test.tsv /tmp/DeBERTa/glue_tasks/QQP/test.tsv
# !/content/DeBERTa/experiments/glue/qqp_base.sh
# Out:
# /content/DeBERTa/DeBERTa/apps/train.py:13: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import OrderedDict, Mapping, Sequence
# ...

# %% [markdown]
# 测试在SemEval2014上加字典知识INSERTION后的效果

# %% [markdown]
# 程序运行时，会保存大量的log日志到该目录下，所以需要定期清空

# %%
# !rm -rf /tmp/ttonly #可能要定期清空缓存

# %%
# !cp /content/Git_repository1/all_data/14/output_know/train.tsv /tmp/DeBERTa/glue_tasks/QQP/train.tsv
# !cp /content/Git_repository1/all_data/14/output_know/dev.tsv /tmp/DeBERTa/glue_tasks/QQP/dev.tsv
# !cp /content/Git_repository1/all_data/14/output_know/test.tsv /tmp/DeBERTa/glue_tasks/QQP/test.tsv
# !cp /content/DictionaryFused-E2E-ABSA/datasets/laprest14/output_know_insert/train.tsv /tmp/DeBERTa/glue_tasks/QQP/train.tsv
# !cp /content/DictionaryFused-E2E-ABSA/datasets/laprest14/output_know_insert/dev.tsv /tmp/DeBERTa/glue_tasks/QQP/dev.tsv
# !cp /content/DictionaryFused-E2E-ABSA/datasets/laprest14/output_know_insert/test.tsv /tmp/DeBERTa/glue_tasks/QQP/test.tsv
# !/content/DeBERTa/experiments/glue/qqp_base.sh
# Out:
# /content/DeBERTa/DeBERTa/apps/train.py:13: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import OrderedDict, Mapping, Sequence
# ...

# %% [markdown]
# 测试在SemEval2015上加字典知识后INSERTION的效果.

# %%
# !rm -rf /tmp/ttonly
# !cp /content/Git_repository1/all_data/rest15/output_know/train.tsv /tmp/DeBERTa/glue_tasks/QQP/train.tsv
# !cp /content/Git_repository1/all_data/rest15/output_know/dev.tsv /tmp/DeBERTa/glue_tasks/QQP/dev.tsv
# !cp /content/Git_repository1/all_data/rest15/output_know/test.tsv /tmp/DeBERTa/glue_tasks/QQP/test.tsv
# !cp /content/DictionaryFused-E2E-ABSA/datasets/rest15/output_know_insert/train.tsv /tmp/DeBERTa/glue_tasks/QQP/train.tsv
# !cp /content/DictionaryFused-E2E-ABSA/datasets/rest15/output_know_insert/dev.tsv /tmp/DeBERTa/glue_tasks/QQP/dev.tsv
# !cp /content/DictionaryFused-E2E-ABSA/datasets/rest15/output_know_insert/test.tsv /tmp/DeBERTa/glue_tasks/QQP/test.tsv
# !/content/DeBERTa/experiments/glue/qqp_base.sh
# Out:
# /content/DeBERTa/DeBERTa/apps/train.py:13: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import OrderedDict, Mapping, Sequence
# ...

# %% [markdown]
# 测试在SemEval2016上加字典知识后INSERTION的效果

# %%
# !rm -rf /tmp/ttonly #可能要定期清空缓存
# !cp /content/Git_repository1/all_data/rest16/output_know/train.tsv /tmp/DeBERTa/glue_tasks/QQP/train.tsv
# !cp /content/Git_repository1/all_data/rest16/output_know/dev.tsv /tmp/DeBERTa/glue_tasks/QQP/dev.tsv
# !cp /content/Git_repository1/all_data/rest16/output_know/test.tsv /tmp/DeBERTa/glue_tasks/QQP/test.tsv
# !cp /content/DictionaryFused-E2E-ABSA/datasets/rest16/output_know_insert/train.tsv /tmp/DeBERTa/glue_tasks/QQP/train.tsv
# !cp /content/DictionaryFused-E2E-ABSA/datasets/rest16/output_know_insert/dev.tsv /tmp/DeBERTa/glue_tasks/QQP/dev.tsv
# !cp /content/DictionaryFused-E2E-ABSA/datasets/rest16/output_know_insert/test.tsv /tmp/DeBERTa/glue_tasks/QQP/test.tsv
# !/content/DeBERTa/experiments/glue/qqp_base.sh
# Out:
# /content/DeBERTa/DeBERTa/apps/train.py:13: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import OrderedDict, Mapping, Sequence
# ...

# %% [markdown]
# 跑在aclshortdata上的增加知识后INSERTION的结果

# %%
# !rm -rf /tmp/ttonly
# !cp /content/Git_repository1/output/output_know/train.tsv /tmp/DeBERTa/glue_tasks/QQP/train.tsv
# !cp /content/Git_repository1/output/output_know/dev.tsv /tmp/DeBERTa/glue_tasks/QQP/dev.tsv
# !cp /content/Git_repository1/output/output_know/test.tsv /tmp/DeBERTa/glue_tasks/QQP/test.tsv
# !cp /content/DictionaryFused-E2E-ABSA/datasets/acl14shortdata/output_know_insert/train.tsv /tmp/DeBERTa/glue_tasks/QQP/train.tsv
# !cp /content/DictionaryFused-E2E-ABSA/datasets/acl14shortdata/output_know_insert/dev.tsv /tmp/DeBERTa/glue_tasks/QQP/dev.tsv
# !cp /content/DictionaryFused-E2E-ABSA/datasets/acl14shortdata/output_know_insert/test.tsv /tmp/DeBERTa/glue_tasks/QQP/test.tsv
# !/content/DeBERTa/experiments/glue/qqp_base.sh
# Out:
# /content/DeBERTa/DeBERTa/apps/train.py:13: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import OrderedDict, Mapping, Sequence
# ...

# %%
# over
